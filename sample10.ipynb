# %%
# !pip install pandas openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.5.3)
# Requirement already satisfied: openai in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.65.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2022.7.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: six>=1.5 in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\bryan santosa\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm>4->openai) (0.4.6)

# %%
import pandas as pd

# Load data
df = pd.read_csv("final_final_video_comments.csv")  
print(f"Total rows: {len(df)}")
display(df.head(10))  # Show first 10 lines
# Out:
# Total rows: 21488
#       video_id                video_title  \
# 0  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 1  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 2  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 3  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 4  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 5  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 6  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 7  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 8  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 9  ZshDHBFmkqU  Jangan salah pilih kotak😅
#
#                                              comment
# 0  Itu yg bikin kotaknya sendiriya gampang tau lo...
# 1                                        AaaaaaKalah
# 2                               Kasiha banget kk nya
# 3                                       lucu lu bang
# 4  Saran coba JPTOGEL77 bg link nya gak pelit tu ...
# 5                 gila JPTOGEL77 member kasi JP trus
# 6  Akhirnya ngerasain nama nya maxwinemang mantap...
# 7                                               scam
# 8  Makasih bang link gacir nya barusan WD gak lum...
# 9  Up Up Upaku coba bang gacir sltnya ya JPTOGEL7...

# %%
# import openai

# # Configure DeepSeek API
# token = "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"
# endpoint = "https://models.inference.ai.azure.com"
# modelName = "DeepSeek-V3"

# openai.api_key = token
# openai.api_base = endpoint

# %%
# import requests
# import time

# API_KEY = "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"  # Use your actual DeepSeek API key
# ENDPOINT = "https://models.inference.ai.azure.com/chat/completions"

# def correct_spelling_deepseek(text, retries=3, delay=2):
#     """Corrects spelling using DeepSeek API with retries and error handling."""
#     prompt = f"""
#     Correct spelling in this Indonesian text. Preserve gambling terms like 'judi', 'slot', 'bonus'.
#     Don't give any explanations, just the final output.
    
#     Examples:
#     1. "sy mau daptar judi onlen" → "saya mau daftar judi online"
#     2. "promo bonaz 100%" → "promo bonus 100%"
    
#     Correct this: "{text}"
#     """

#     headers = {
#         "Authorization": f"Bearer {API_KEY}",
#         "Content-Type": "application/json"
#     }

#     data = {
#         "model": "DeepSeek-V3",
#         "messages": [{"role": "user", "content": prompt}],
#         "max_tokens": 1000
#     }

#     for attempt in range(retries):
#         try:
#             response = requests.post(ENDPOINT, json=data, headers=headers)
#             response_json = response.json()  # Parse JSON response

#             # Print full response for debugging
#             print(f"API Response: {response_json}")

#             # Check if the response contains "choices"
#             if "choices" in response_json and len(response_json["choices"]) > 0:
#                 choice = response_json["choices"][0]

#                 # ✅ Correctly check if response is valid
#                 if choice["finish_reason"] == "stop":
#                     message_data = choice["message"]
                    
#                     # ✅ Check if "content" exists before accessing
#                     if "content" in message_data:
#                         return message_data["content"].strip()
#                     else:
#                         return "[Content blocked by DeepSeek AI filter]"

#             print(f"Unexpected response format: {response_json}")
#             time.sleep(delay)  # Wait before retrying
#             return text

#         except requests.exceptions.RequestException as e:
#             print(f"Request error: {e}")
#             time.sleep(delay)  # Wait before retrying

#     return text  # Return original text if all retries fail

# %%
# import requests
# import pandas as pd

# # Define function to correct spelling and label comments
# def correct_spelling_deepseek(text):
#     """Corrects spelling and classifies comments using a locally hosted Mistral model via LM Studio API."""
#     prompt = f"""
#     You are a data labeler and a spell checker with the main task of interpreting social media comments on trending YouTube Shorts videos from Indonesia and assigning a label to each of them . 
#     Your task is to spellcheck and interpret the meaning of the social media comments. 
#     Label the comment as either "Online Gambling Promotion" if it promotes online gambling, or "No Online Gambling Promotion" otherwise.
    
#     Correct the spelling in this Indonesian text if it is not understandable. Preserve gambling terms like 'judi', 'slot', 'bonus', 
#     'gachor', 'maxwin', or any other keywords that might indicate online gambling promotions.
    
#     Don't give any explanations—just output the corrected or uncorrected comment along with its label.
#     Label the comment as either "Online Gambling Promotion" if it promotes online gambling, or "No Online Gambling Promotion" otherwise.

#     Example of Expected Format:
#     1. Input : "sy mau daptar judi onlen" -> Output : "saya mau daftar judi online, Online Gambling Promotion"
#     2. Input : "bersandar teras rumah sembari ngopi bermain permainan nyelot jptogel77 nikmat sekaleh" → 
#        Output : "bersandar teras rumah sembari ngopi bermain permainan slot jptogel77 nikmat sekali, Online Gambling Promotion"
#     3. Input :"lagi nunggu ojol di pinggir jalan" → Output : "lagi nunggu ojol di pinggir jalan, No Online Gambling Promotion"
#     the output should be the words inside the ""(parantheses) after "Output :"
#     Correct this: "{text}"
#     """

#     url = "http://localhost:1234/v1/completions"  # LM Studio API endpoint
    
#     payload = {
#         "model": "mistral-7b-instruct@q3_k_l",  # Ensure correct model name
#         "prompt": prompt,
#         "max_tokens": 100,
#         "temperature": 0.3
#     }

#     headers = {"Content-Type": "application/json"}

#     try:
#         response = requests.post(url, headers=headers, json=payload)
#         response_json = response.json()

#         # Debugging: Print full response
#         print(f"API Response: {response_json}")

#         # Extract the generated text
#         corrected_text = response_json["choices"][0]["text"].strip()

#         # Check if the response follows the format "Corrected Text, Label"
#         if "," in corrected_text:
#             corrected_comment, label = corrected_text.rsplit(",", 1)  # Split from the last comma
#             return corrected_comment.strip(), label.strip()
#         else:
#             return text, "Unknown"  # Fallback if format is unexpected

#     except Exception as e:
#         print(f"Error: {e}")
#         return text, "Error"

# %%
df.head(10)
# Out:
#       video_id                video_title  \
# 0  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 1  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 2  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 3  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 4  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 5  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 6  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 7  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 8  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 9  ZshDHBFmkqU  Jangan salah pilih kotak😅
#
#                                              comment
# 0  Itu yg bikin kotaknya sendiriya gampang tau lo...
# 1                                        AaaaaaKalah
# 2                               Kasiha banget kk nya
# 3                                       lucu lu bang
# 4  Saran coba JPTOGEL77 bg link nya gak pelit tu ...
# 5                 gila JPTOGEL77 member kasi JP trus
# 6  Akhirnya ngerasain nama nya maxwinemang mantap...
# 7                                               scam
# 8  Makasih bang link gacir nya barusan WD gak lum...
# 9  Up Up Upaku coba bang gacir sltnya ya JPTOGEL7...

# %%
import re  # Add this at the top of your script for regex processing

def normalize_text(text):
    """Removes special symbols and extra spaces while preserving important content."""
    text = re.sub(r"[^\w\s,]", "", text)  # Remove non-word characters except spaces and commas
    text = re.sub(r"\s+", " ", text).strip()  # Normalize extra spaces
    return text

# %%
import requests
import json
import pandas as pd
import time
import os

# === CONFIGURATION ===
df_sample = df.head(10).copy() 
INPUT_FILE = df_sample  # Input file with comments
OUTPUT_FILE = "processed_comments.csv"  # Output file to store results
BATCH_SIZE = 10                # Save progress every 100 comments
API_URL = "http://localhost:1234/v1/completions"  # LM Studio API endpoint
MODEL_NAME = "mistral-7b-instruct@q3_k_l"  # Model in LM Studio
MAX_RETRIES = 5                 # Number of retries for API errors
PROMPT_DELAY = 0.5           # Time (seconds) between each API request

# === LOAD DATA & RESUME IF NECESSARY ===
try: 
    processed_df = pd.read_csv(OUTPUT_FILE)  
    last_index = len(processed_df) - 1  
    print(f"Resuming from index {last_index + 1}...")
except FileNotFoundError:
    df_sample["label"] = ""  
    last_index = -1  

# === FUNCTION TO HANDLE API REQUESTS WITH RETRIES ===
def correct_spelling_deepseek(text):
    """Calls LM Studio API to correct spelling and label the comment."""
    prompt = f"""
You are a data labeler and a spell checker with the main task of interpreting social media comments on trending YouTube Shorts videos from Indonesia and assigning a label to each of them. 
Your task is to spellcheck and interpret the meaning of the social media comments. 
Label the comment as either "Online Gambling Promotion" if it promotes online gambling, or "No Online Gambling Promotion" otherwise.

Correct the spelling in this Indonesian text if it is not understandable. Preserve gambling terms like 'judi', 'slot', 'bonus', 
'gachor', 'maxwin', or any other keywords that might indicate online gambling promotions. 

**Output strictly in this format:**  
`<corrected_comment>, <label>` 
Do not add punctuations to the comments only add them to differentiate comment and label

Don't give any explanations—just output the corrected or uncorrected comment along with its label. Make sure the output follows this format:
Corrected comment without parentheses: "<corrected_comment>, <label>"

Example of Expected Format:
1. Input : sy mau daptar judi onlen -> "saya mau daftar judi online, Online Gambling Promotion"
2. Input : bersandar teras rumah sembari ngopi bermain permainan nyelot jptogel77 nikmat sekaleh → 
    "bersandar teras rumah sembari ngopi bermain permainan slot jptogel77 nikmat sekali, Online Gambling Promotion"
3. Input : lagi nunggu ojol di pinggir jalan →  "lagi nunggu ojol di pinggir jalan, No Online Gambling Promotion"

Output format enforcement: **Do NOT include explanations or extra words. Only return the formatted result.**  

Text to process: "{text}"
"""

    payload = {
        "model": MODEL_NAME,
        "prompt": prompt,
        "max_tokens": 80,
        "temperature": 0.3
    }

    headers = {"Content-Type": "application/json"}

    for attempt in range(MAX_RETRIES):
        try:
            response = requests.post(API_URL, headers=headers, json=payload)
            response_json = response.json()
            
            # Extract the generated response
            corrected_text = response_json["choices"][0]["text"].strip()
            return corrected_text if corrected_text else text  

        except Exception as e:
            print(f"Error on attempt {attempt+1}: {e}")
            time.sleep(2 ** attempt)  # Exponential backoff (2s, 4s, 8s...)

    return text  

# === PROCESS COMMENTS ===
for i in range(last_index + 1, len(df_sample)):
    comment = df_sample.loc[i, "comment"]
    processed_text = correct_spelling_deepseek(comment).replace("\\", "").replace('"',"")
    # print(correct_spelling_deepseek(comment))
    print(processed_text)
    try:
        processed_text = normalize_text(processed_text).strip('"')  # Apply normalization
        print(f"processed_text : {processed_text}")
        corrected_comment, label = processed_text.rsplit(",", 1)
        corrected_comment = corrected_comment.strip()
        label = label.strip()
    except ValueError:
        corrected_comment, label = processed_text.strip(), "ERROR"

    df_sample.loc[i, "comment"] = corrected_comment  
    df_sample.loc[i, "label"] = label

    # Save progress every BATCH_SIZE comments
    if (i + 1) % BATCH_SIZE == 0 or i == len(df_sample) - 1:
        df_sample.iloc[:i+1].to_csv(OUTPUT_FILE, index=False)
        print(f"✅ Saved progress at {i+1} comments")

    time.sleep(PROMPT_DELAY)  # === Added Delay Between Requests ===
    print()
print("🎉 Processing complete! Data saved.")
# Out:
# Resuming from index 7...
# `scam, No Online Gambling Promotion`
# processed_text : scam, No Online Gambling Promotion
#
# Output: Terima kasih bang link gacor nyata barusan WD, gak lumayan kopi rokok mantap depo WD aman lancar, jaya emang enak main slot JPTOGEL77, Online Gambling Promotion
# processed_text : Output Terima kasih bang link gacor nyata barusan WD, gak lumayan kopi rokok mantap depo WD aman lancar, jaya emang enak main slot JPTOGEL77, Online Gambling Promotion
#
# Output: Up Up Upaku coba bang gacir slotnya ya JPTOGEL77 pantes ramah kali comment hahaha, Online Gambling Promotion
# processed_text : Output Up Up Upaku coba bang gacir slotnya ya JPTOGEL77 pantes ramah kali comment hahaha, Online Gambling Promotion
# ✅ Saved progress at 10 comments
#
# 🎉 Processing complete! Data saved.

# %%
# # Limit to first 10 comments
# df_sample = df.head(4).copy()

# # Apply correction (add progress bar)
# from tqdm.notebook import tqdm
# tqdm.pandas()

# df_sample["corrected_comment"] = df_sample["comment"].progress_apply(correct_spelling_deepseek)

# # Show results
# display(df_sample[["video_id", "comment", "corrected_comment"]])
# df_sample["corrected_comment"]

# %%
# df_sample = df.head(4).copy()
# df_sample[["corrected_comment", "label"]] = df_sample["comment"].apply(
#     lambda x: pd.Series(correct_spelling_deepseek(x))
# )

# # Print final DataFrame
# print(df_sample)

# %%
# correct_spelling_deepseek(text = "lucu lu bang")

# %%
df_sample
# Out:
#       video_id                video_title  \
# 0  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 1  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 2  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 3  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 4  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 5  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 6  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 7  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 8  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 9  ZshDHBFmkqU  Jangan salah pilih kotak😅
#
#                                              comment
# 0  Itu yg bikin kotaknya sendiriya gampang tau lo...
# 1                                        AaaaaaKalah
# 2                               Kasiha banget kk nya
# 3                                       lucu lu bang
# 4  Saran coba JPTOGEL77 bg link nya gak pelit tu ...
# 5                 gila JPTOGEL77 member kasi JP trus
# 6  Akhirnya ngerasain nama nya maxwinemang mantap...
# 7                                               scam
# 8  Makasih bang link gacir nya barusan WD gak lum...
# 9  Up Up Upaku coba bang gacir sltnya ya JPTOGEL7...

# %%
df_sample
# Out:
#       video_id                video_title  \
# 0  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 1  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 2  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 3  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 4  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 5  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 6  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 7  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 8  ZshDHBFmkqU  Jangan salah pilih kotak😅
# 9  ZshDHBFmkqU  Jangan salah pilih kotak😅
#
#                                              comment
# 0  Itu yg bikin kotaknya sendiriya gampang tau lo...
# 1                                        AaaaaaKalah
# 2                               Kasiha banget kk nya
# 3                                       lucu lu bang
# 4  Saran coba JPTOGEL77 bg link nya gak pelit tu ...
# 5                 gila JPTOGEL77 member kasi JP trus
# 6  Akhirnya ngerasain nama nya maxwinemang mantap...
# 7                                               scam
# 8  Makasih bang link gacir nya barusan WD gak lum...
# 9  Up Up Upaku coba bang gacir sltnya ya JPTOGEL7...

# %%
df_sample["corrected_comment"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'corrected_comment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_sample["corrected_comment"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'corrected_comment'
